# %%
import numpy as np

# %% [markdown]
# .dtype metodi

# %%
arr1=np.array([12,23,3.4,5])
arr1.dtype
# Out:
# dtype('float64')

# %%
arr2=np.array([10,2,11,3], dtype=np.int16)
arr2.dtype
# Out:
# dtype('int16')

# %%
arr3=np.array([56,545,2,1,14], dtype=np.float64)
arr3
# Out:
# array([ 56., 545.,   2.,   1.,  14.])

# %% [markdown]
# .astype metodi

# %%
int_arr1=arr1.astype(np.int64)
int_arr1
# Out:
# array([12, 23,  3,  5])

# %%
float_arr2=arr2.astype(np.float32)
float_arr2
# Out:
# array([10.,  2., 11.,  3.], dtype=float32)
