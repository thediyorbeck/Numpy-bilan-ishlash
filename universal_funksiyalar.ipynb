# %%
import numpy as np

# %%
arr1=np.random.randint(10,100, size=(6))
arr1
# Out:
# array([80, 30, 32, 28, 52, 84])

# %% [markdown]
# unary funksiyalar - bitta argument qabul qiluvchi funksiyalar

# %%
np.sqrt(arr1)
# Out:
# array([8.94427191, 5.47722558, 5.65685425, 5.29150262, 7.21110255,
#        9.16515139])

# %%
np.square(arr1)
# Out:
# array([6400,  900, 1024,  784, 2704, 7056])

# %%
np.log(arr1)
# Out:
# array([4.38202663, 3.40119738, 3.4657359 , 3.33220451, 3.95124372,
#        4.4308168 ])

# %% [markdown]
# binary- 2 ta argument qabul qiluvchi funksiya

# %%
arr2=np.random.randint(10,100, size=(6))
arr2
# Out:
# array([72, 52, 21, 18, 55, 89])

# %%
np.sign(arr2)
# Out:
# array([1, 1, 1, 1, 1, 1])

# %%
np.maximum(arr1,arr2)
# Out:
# array([80, 52, 32, 28, 55, 89])

# %%
np.add(arr1,arr2)
# Out:
# array([152,  82,  53,  46, 107, 173])

# %%
np.mod(arr1,arr2)
# Out:
# array([ 8, 30, 11, 10, 52, 84])
